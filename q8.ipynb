# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Problem = '...'
StringSubset = []
StringSubsetProduct = []
for i in range(1000-13):
    StringSubset.append(Problem[i:i+13])
    TempProduct = 1
    for j in range(13):
        TempString = StringSubset[i]
        TempProduct = int(TempString[j])*TempProduct
    StringSubsetProduct.append(TempProduct)
print('13 digit sequence that gives the greatest product:',StringSubset[StringSubsetProduct.index(max(StringSubsetProduct))])
print('The Product of those 13 digits:',max(StringSubsetProduct))
# Out:
# 13 digit sequence that gives the greatest product: 5576689664895
# The Product of those 13 digits: 23514624000

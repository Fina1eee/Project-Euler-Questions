# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fib1 = 1
fib2 = 2
fib3 = fib1 + fib2
sum = 2
while (fib3 < 4000000):
    fib1 = fib2
    fib2 = fib3
    fib3 = fib1+fib2
    if (fib3 % 2 == 0):
        sum = sum + fib3
print(sum)
# Out:
# 4613732

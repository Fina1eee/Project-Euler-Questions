# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
def Problem9():
    for a in range(1,1001):
        for b in range(1,1001):
            for c in range(1,1001):
                if (a + b + c == 1000) and (a**2 + b**2 == c**2):
                    print('a =',a,'b =',b,'c =',c)
                    print('Product of a,b,c =',a*b*c)
                    return a*b*c
x = Problem9()
# Out:
# a = 200 b = 375 c = 425
# Product of a,b,c = 31875000

# %% [markdown]
# Below is a more efficient method after doing some math on paper.

# %%
for a in range(1,292):
    b = int((2000*a - 1000**2) / (2*a-2000))
    c = int(np.sqrt(a**2 + b**2))
    if (a + b + c == 1000):
        print('a =',a,'b =',b,'c =',c)
        print('Product of a,b,c =',a*b*c)
# Out:
# a = 200 b = 375 c = 425
# Product of a,b,c = 31875000
